# %%
from data_processing import DataProcesser

# %% [markdown]
# ## Load Data

# %%
processor = DataProcesser(dataset_dir="data.pkl")

train_x, train_y, test_x, test_y = processor.load_data()

# %% [markdown]
# ## visualize

# %%
processor.display_img(train_x, train_y)
