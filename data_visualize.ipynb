# %%
from data_pipeline import DataPipeline

# %% [markdown]
# ## Load Data

# %%
data_pipeline = DataPipeline(dataset_dir="data.pkl")

train_x, train_y, valid_x, valid_y, test_x, test_y = data_pipeline.get_train_valid_test()

# %%
print(f"training data : {len(train_x)}")
print(f"validation data : {len(valid_x)}")
print(f"Testing data : {len(test_x)}")
# Out:
# training data : 54000
# validation data : 6000
# Testing data : 27561

# %%
train_x[0].dtype
# Out:
# dtype('float64')

# %%
data_pipeline.class_names
# Out:
# ['၀', '၁', '၂', '၃', '၄', '၅', '၆', '၇', '၈', '၉']

# %% [markdown]
# ## Visualize

# %%
data_pipeline.display_img(train_x, train_y)
